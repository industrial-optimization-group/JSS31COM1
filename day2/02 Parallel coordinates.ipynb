# %%
import plotly.io as pio
import plotly.express as ex
import plotly.subplots as sp

import numpy as np
import pandas as pd

# %%
pio.templates.default = "presentation"

# %%
data_iris = ex.data.iris()
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
ex.parallel_coordinates(
    data_iris,
    dimensions=[
        "sepal_width",
        "sepal_length",
        "petal_width",
        "petal_length",
        "species_id",],
    color="species_id", 
)

# %%
u = np.linspace(0,1,100)
v1 = u + 10000000
v2 = -u
v3 = (0.25 - (u-0.5) ** 2) ** 0.5
rand = np.random.rand(100)
# v4 = Add other interesting patterns

data = pd.DataFrame(
    np.vstack((u, v1, v2, v3, rand)).T,
    columns = ["input", "proportional", "inverse", "circle", "random"],
)

# %%
two_columns = ["input", "random"]
ex.scatter(data, x=two_columns[0], y=two_columns[1])

# %%
ex.parallel_coordinates(data, dimensions=two_columns)

# %%
sb.make_subplots?
# Out:
# Signature:
# sb.make_subplots(
#     rows=1,
#     cols=1,
#     shared_xaxes=False,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=None,
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs,
# ) -> plotly.graph_objs._figure.Figure
# Docstring:
# Return an instance of plotly.graph_objs.Figure with predefined subplots
# configured in 'layout'.
#
# Parameters
# ----------
# rows: int (default 1)
#     Number of rows in the subplot grid. Must be greater than zero.
#
# cols: int (default 1)
#     Number of columns in the subplot grid. Must be greater than zero.
#
# shared_xaxes: boolean or str (default False)
#     Assign shared (linked) x-axes for 2D cartesian subplots
#
# ...
